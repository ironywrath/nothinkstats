# %% [markdown]
# ## Exponential distribution

# %% [markdown]
# ### 指数分布

# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np

import nsfg
import first
import analytic

import thinkstats2
import thinkplot

import nothinkstats2
import nothinkplot

# %%
thinkplot.PrePlot(4)
for lam in [2.0, 1, 0.5, 8.0]:
    xs, ps = thinkstats2.RenderExpoCdf(lam, 0, 3.0, 50)
    label = r'$lambda=%g$' % lam
    thinkplot.Plot(xs, ps, label=label)
    
thinkplot.Config(title='Exponential CDF', xlabel='x' , ylabel='CDF', loc='lower right')

# %%
df = analytic.ReadBabyBoom()
df
# Out:
#     time  sex  weight_g  minutes
# 0      5    1      3837        5
# 1    104    1      3334       64
# 2    118    2      3554       78
# 3    155    2      3838      115
# 4    257    2      3625      177
# 5    405    1      2208      245
# 6    407    1      1745      247
# 7    422    2      2846      262
# 8    431    2      3166      271
# 9    708    2      3520      428
# 10   735    2      3380      455
# 11   812    2      3294      492
# 12   814    1      2576      494
# 13   909    1      3208      549
# 14  1035    2      3521      635
# 15  1049    1      3746      649
# 16  1053    1      3523      653
# 17  1133    2      2902      693
# 18  1209    2      2635      729
# 19  1256    2      3920      776
# 20  1305    2      3690      785
# 21  1406    1      3430      846
# 22  1407    1      3480      847
# 23  1433    1      3116      873
# 24  1446    1      3428      886
# 25  1514    2      3783      914
# 26  1631    2      3345      991
# ...

# %%
diffs = df.minutes.diff()
diffs
# Out:
# 0       NaN
# 1      59.0
# 2      14.0
# 3      37.0
# 4      62.0
# 5      68.0
# 6       2.0
# 7      15.0
# 8       9.0
# 9     157.0
# 10     27.0
# 11     37.0
# 12      2.0
# 13     55.0
# 14     86.0
# 15     14.0
# 16      4.0
# 17     40.0
# 18     36.0
# 19     47.0
# 20      9.0
# 21     61.0
# 22      1.0
# 23     26.0
# 24     13.0
# 25     28.0
# 26     77.0
# 27     26.0
# 28     45.0
# 29     25.0
# 30     18.0
# 31     29.0
# 32     15.0
# 33     38.0
# 34      2.0
# 35      2.0
# 36     19.0
# 37     27.0
# 38     14.0
# 39     13.0
# 40     19.0
# 41     54.0
# 42     70.0
# 43     28.0
# Name: minutes, dtype: float64

# %%
cdf = thinkstats2.Cdf(diffs, label='actual')
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='Time between births', ylabel='CDF')

# %%
thinkplot.Cdf(cdf, complement=True)
thinkplot.Config(xlabel='Time between births',
                ylabel='CDF', yscale='log', loc='upper right')

# %% [markdown]
# ### Play ground

# %%
import neverthinkstats2

# %%
mpgdf = neverthinkstats2.ReadmpgData()
mpgdf
# Out:
#      Unnamed: 0 manufacturer               model  displ  year  cyl  \
# 0             1         audi                  a4    1.8  1999    4
# 1             2         audi                  a4    1.8  1999    4
# 2             3         audi                  a4    2.0  2008    4
# 3             4         audi                  a4    2.0  2008    4
# 4             5         audi                  a4    2.8  1999    6
# 5             6         audi                  a4    2.8  1999    6
# 6             7         audi                  a4    3.1  2008    6
# 7             8         audi          a4 quattro    1.8  1999    4
# 8             9         audi          a4 quattro    1.8  1999    4
# 9            10         audi          a4 quattro    2.0  2008    4
# 10           11         audi          a4 quattro    2.0  2008    4
# 11           12         audi          a4 quattro    2.8  1999    6
# 12           13         audi          a4 quattro    2.8  1999    6
# ...

# %%
displ_diff = mpgdf.displ.diff()
displ_diff
# Out:
# 0      NaN
# 1      0.0
# 2      0.2
# 3      0.0
# 4      0.8
# 5      0.0
# 6      0.3
# 7     -1.3
# 8      0.0
# 9      0.2
# 10     0.0
# 11     0.8
# 12     0.0
# 13     0.3
# 14     0.0
# 15    -0.3
# 16     0.3
# 17     1.1
# 18     1.1
# 19     0.0
# 20     0.0
# 21     0.4
# 22     0.3
# 23    -0.3
# 24     0.0
# 25     0.5
# 26     0.0
# 27     0.8
# 28    -1.7
# 29     0.0
#       ...
# 204    0.0
# 205    0.6
# 206    0.0
# 207   -2.0
# 208    0.0
# 209    0.0
# 210    0.0
# 211    0.8
# 212   -0.9
# 213    0.1
# 214    0.0
# 215    0.0
# 216    0.0
# 217    0.5
# 218    0.0
# 219    0.3
# 220    0.0
# 221   -0.9
# 222    0.0
# 223    0.1
# 224    0.0
# 225    0.5
# 226    0.0
# 227   -0.7
# 228    0.0
# 229    0.2
# 230    0.0
# 231    0.8
# 232    0.0
# 233    0.8
# Name: displ, Length: 234, dtype: float64

# %%
cdf = thinkstats2.Cdf(displ_diff,label='diff')

# %%
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='displ diff', ylabel='CDF')

# %%
thinkplot.Cdf(cdf, complement=True)
thinkplot.Config(xlabel = 'displ diff')
